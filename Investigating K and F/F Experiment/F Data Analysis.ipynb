# %% [markdown]
# Importing relevant libraries for data wrangling

# %%
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_baseline = pd.DataFrame()
cols_list_baseline = [1]
for i in range(8, (60*7 + 2), 7):  # Strategy is in every 7th column starting at the 6th column for 60 traders
    cols_list_baseline.append(i)

df_baseline_row_times = []
for i in range(0, 2588400, 3600):
    df_baseline_row_times.append(i)

df_baseline_col_names = ["time"]
for i in range(30):
    if i < 10:
        df_baseline_col_names.append("B0" + str(i))
    else:
        df_baseline_col_names.append("B" + str(i))

for i in range(30):
    if i < 10:
        df_baseline_col_names.append("S0" + str(i))
    else:
        df_baseline_col_names.append("S" + str(i))


for i in range(10):
    #df_k6_i = pd.DataFrame()
    df_baseline_i_list = []
    df_baseline_i_list.append(pd.read_csv("PRDE_Baseline_" + str(i) + "_strats.csv", header=None, usecols=cols_list_baseline))
    df_baseline_i = pd.concat(df_baseline_i_list)

    df_baseline_i.columns = df_baseline_col_names
    df_baseline_i.set_index("time", inplace=True)
    df_baseline[f"Total PPS {i}"] = df_baseline_i.sum(axis=1)

df_baseline["Mean PPS"] = df_baseline.sum(axis=1) / 10
df_baseline
# Out:
#          Total PPS 0  Total PPS 1  Total PPS 2  Total PPS 3  Total PPS 4  \
# time
# 0           0.000000     0.000000     0.000000     0.000000     0.000000
# 3600       51.241942    51.572218    59.144166    53.731111    57.800283
# 7200        0.000000     0.000000     0.000000     0.000000     0.000000
# 10800      45.421111    47.071385    44.715276    49.482224    49.849218
# 14400      45.235692    47.297085    44.511076    49.444027    49.475395
# ...              ...          ...          ...          ...          ...
# 2574000    61.802804    55.349352    63.925518    57.113470    55.907416
# 2577600    61.564044    55.238038    63.922339    57.241173    55.877991
# 2581200    62.818534    57.009867    63.186363    59.971884    59.172966
# 2584800    62.753915    56.689779    63.280112    59.865836    59.538259
# 2588400    63.234244    56.989271    63.943964    53.461130    58.599784
#
#          Total PPS 5  Total PPS 6  Total PPS 7  Total PPS 8  Total PPS 9  \
# time
# ...

# %%
df_F12 = pd.DataFrame()
cols_list_F12 = [1]
for i in range(8, (60*7 + 2), 7):  # Strategy is in every 7th column starting at the 6th column for 60 traders
    cols_list_F12.append(i)

df_F12_row_times = []
for i in range(0, 2588400, 3600):
    df_F12_row_times.append(i)

df_F12_col_names = ["time"]
for i in range(30):
    if i < 10:
        df_F12_col_names.append("B0" + str(i))
    else:
        df_F12_col_names.append("B" + str(i))

for i in range(30):
    if i < 10:
        df_F12_col_names.append("S0" + str(i))
    else:
        df_F12_col_names.append("S" + str(i))


for i in range(10):
    #df_k6_i = pd.DataFrame()
    df_F12_i_list = []
    df_F12_i_list.append(pd.read_csv("PRDE_Baseline_F=1.2_" + str(i) + "_strats.csv", header=None, usecols=cols_list_F12))
    df_F12_i = pd.concat(df_F12_i_list)

    df_F12_i.columns = df_F12_col_names
    df_F12_i.set_index("time", inplace=True)
    df_F12[f"Total PPS {i}"] = df_F12_i.sum(axis=1)

df_F12["Mean PPS"] = df_F12.sum(axis=1) / 10
df_F12
# Out:
#          Total PPS 0  Total PPS 1  Total PPS 2  Total PPS 3  Total PPS 4  \
# time
# 0           0.000000          NaN          NaN          NaN          NaN
# 3600       52.363332    48.062778    53.645585    54.755276    56.541114
# 7200        0.000000     0.000000     0.000000     0.000000     0.000000
# 10800      52.718055    48.642220    52.736387    52.513612    57.698353
# 14400      52.774030    49.180831    52.459305    52.272222    57.649027
# ...              ...          ...          ...          ...          ...
# 2574000    63.889846    62.318209    67.222860    64.978905    63.768551
# 2577600    63.993934    62.188113    67.116870    64.840802    63.676378
# 2581200    63.194981    64.036335    66.153063    69.370100    67.562438
# 2584800    63.247947    63.682143    66.318240    69.327477    67.314157
# 2588400    64.519099    62.241407    59.623888    64.004936    62.847240
#
#          Total PPS 5  Total PPS 6  Total PPS 7  Total PPS 8  Total PPS 9  \
# time
# ...

# %%
df_F16 = pd.DataFrame()
cols_list_F16 = [1]
for i in range(8, (60*7 + 2), 7):  # Strategy is in every 7th column starting at the 6th column for 60 traders
    cols_list_F16.append(i)

df_F16_row_times = []
for i in range(0, 2588400, 3600):
    df_F16_row_times.append(i)

df_F16_col_names = ["time"]
for i in range(30):
    if i < 10:
        df_F16_col_names.append("B0" + str(i))
    else:
        df_F16_col_names.append("B" + str(i))

for i in range(30):
    if i < 10:
        df_F16_col_names.append("S0" + str(i))
    else:
        df_F16_col_names.append("S" + str(i))


for i in range(10):
    df_F16_i_list = []
    df_F16_i_list.append(pd.read_csv("PRDE_Baseline_F=1.6_" + str(i) + "_strats.csv", header=None, usecols=cols_list_F16))
    df_F16_i = pd.concat(df_F16_i_list)

    df_F16_i.columns = df_F16_col_names
    df_F16_i.set_index("time", inplace=True)
    df_F16[f"Total PPS {i}"] = df_F16_i.sum(axis=1)

df_F16["Mean PPS"] = df_F16.sum(axis=1) / 10
df_F16
# Out:
#          Total PPS 0  Total PPS 1  Total PPS 2  Total PPS 3  Total PPS 4  \
# time
# 0           0.000000     0.000000          NaN          NaN     0.000000
# 3600       51.156388    44.529723    55.513910    54.937797    62.101110
# 7200        0.000000     0.000000     0.000000     0.000000     0.000000
# 10800      53.610526    51.875554    53.217497    51.433096    50.211020
# 14400       0.000000     0.000000    53.182081     0.000000    50.393987
# ...              ...          ...          ...          ...          ...
# 2574000    65.838126    67.601837    66.689129    66.686527    64.879983
# 2577600    65.781466    67.602322    66.626002    66.728433    64.983440
# 2581200    64.706747    66.654482    65.462900    68.358512    64.267375
# 2584800    64.921975    66.828398    65.452964    68.392892    64.340877
# 2588400    63.494864    64.532818    64.265524    66.576555    63.550641
#
#          Total PPS 5  Total PPS 6  Total PPS 7  Total PPS 8  Total PPS 9  \
# time
# ...

# %%
df_F20 = pd.DataFrame()
cols_list_F20 = [1]
for i in range(8, (60*7 + 2), 7):  # Strategy is in every 7th column starting at the 6th column for 60 traders
    cols_list_F20.append(i)

df_F20_row_times = []
for i in range(0, 2588400, 3600):
    df_F20_row_times.append(i)

df_F20_col_names = ["time"]
for i in range(30):
    if i < 10:
        df_F20_col_names.append("B0" + str(i))
    else:
        df_F20_col_names.append("B" + str(i))

for i in range(30):
    if i < 10:
        df_F20_col_names.append("S0" + str(i))
    else:
        df_F20_col_names.append("S" + str(i))


for i in range(10):
    df_F20_i_list = []
    df_F20_i_list.append(pd.read_csv("PRDE_Baseline_F=2.0_" + str(i) + "_strats.csv", header=None, usecols=cols_list_F20))
    df_F20_i = pd.concat(df_F20_i_list)

    df_F20_i.columns = df_F20_col_names
    df_F20_i.set_index("time", inplace=True)
    df_F20[f"Total PPS {i}"] = df_F20_i.sum(axis=1)

df_F20["Mean PPS"] = df_F20.sum(axis=1) / 10
df_F20
# Out:
#          Total PPS 0  Total PPS 1  Total PPS 2  Total PPS 3  Total PPS 4  \
# time
# 0           0.000000          NaN     0.000000     0.000000     0.000000
# 3600       44.469168    53.139754    45.468610    57.973891    54.653051
# 7200        0.000000     0.000000     0.000000     0.000000     0.000000
# 10800      47.715392    52.438057    45.707010    54.172752    55.341433
# 14400       0.000000    52.462083    46.086111    54.530402    55.130002
# ...              ...          ...          ...          ...          ...
# 2574000    66.389575    68.225106    65.870800    67.667251    66.110508
# 2577600    66.224145    68.159971    65.635673    67.666818    66.147508
# 2581200    62.069159    66.575104    63.529624    71.053965    60.900665
# 2584800    62.016045    66.846217    63.527603    70.930227    61.146204
# 2588400    68.500055    59.771357    66.114276    68.078396    70.820605
#
#          Total PPS 5  Total PPS 6  Total PPS 7  Total PPS 8  Total PPS 9  \
# time
# ...

# %%
plt.plot((df_baseline.index / (60*60*24)), df_baseline["Mean PPS"].rolling(15).mean(), color="tab:blue", label="F = 0.8 (Baseline)", alpha=1)
plt.plot((df_F12.index / (60*60*24)), df_F12["Mean PPS"].rolling(15).mean(), color="tab:orange", label="F = 1.2", alpha=1)
plt.plot((df_F16.index / (60*60*24)), df_F16["Mean PPS"].rolling(15).mean(), color="tab:green", label="F = 1.6", alpha=1)
plt.plot((df_F20.index / (60*60*24)), df_F20["Mean PPS"].rolling(15).mean(), color="tab:red", label="F = 2.0", alpha=1)

plt.xlabel("Day", fontsize=14)
plt.ylabel("Profit Per Second", fontsize=14)
plt.title("Profit: PRDE with varying F and constant k(=4)", fontsize=16)

plt.legend(fontsize=14, loc="lower right")
plt.savefig("PRDE F Investigation.png")
plt.show()

# %%
# Statistical Testing
baseline_means = df_baseline.mean(axis=0)
stats_df = pd.DataFrame(baseline_means, columns=["F=0.8 (Baseline)"])

F12_means = df_F12.mean(axis=0)
F16_means = df_F16.mean(axis=0)
F20_means = df_F20.mean(axis=0)
stats_df["F=1.2"] = F12_means
stats_df["F=1.6"] = F16_means
stats_df["F=2.0"] = F20_means


new_labels = ["Run 0 Mean PPS", "Run 1 Mean PPS", "Run 2 Mean PPS", "Run 3 Mean PPS", "Run 4 Mean PPS",
              "Run 5 Mean PPS", "Run 6 Mean PPS", "Run 7 Mean PPS", "Run 8 Mean PPS", "Run 9 Mean PPS"]


stats_df.drop(index="Mean PPS", inplace=True)
stats_df.index = new_labels
stats_df
# Out:
#                 F=0.8 (Baseline)      F=1.2      F=1.6      F=2.0
# Run 0 Mean PPS         60.786996  63.221990  64.663560  65.925553
# Run 1 Mean PPS         58.352673  63.179146  65.145539  66.393568
# Run 2 Mean PPS         59.229277  63.351697  65.274023  65.785859
# Run 3 Mean PPS         57.787359  63.173256  64.696330  66.910918
# Run 4 Mean PPS         57.332912  63.069954  65.755553  66.373883
# Run 5 Mean PPS         59.388640  63.387203  64.741162  66.015228
# Run 6 Mean PPS         61.073722  62.834387  64.761846  66.655556
# Run 7 Mean PPS         61.299141  63.132395  64.403852  66.211070
# Run 8 Mean PPS         59.627072  62.248571  65.495195  66.004673
# Run 9 Mean PPS         60.268477  62.731703  66.057332  66.313400

# %%
# Visualising with a boxplot
BWP = sns.boxplot(data=stats_df)
BWP.set_ylabel("Mean PPS Per Run", fontsize=14)
BWP.set_title("Mean PPS Per Run: PRDE with Varying k and Constant F(=0.8)", fontsize=16)
plt.savefig("Box_and_Whisker_F.png")
plt.show()

# %%
# Testing for Normality with Shapiro-Wilk test
for col in stats_df.columns:
    SWstatistic, SWpvalue = stats.shapiro(stats_df[col])
    print(f"SW: {col} data is Normally Distributed") if SWpvalue > 0.05 else print(f"SW: {col} data is Not Normally Distributed")

# Confirming Shapiro-Wilk results with Kolmogorov-Smirnov test
for col in stats_df.columns:
    normal_data = (stats_df[col] - stats_df[col].mean())/stats_df[col].std()
    KSstatistic, KSpvalue = stats.kstest(normal_data, "norm")
    print(f"KS: {col} data is Normally Distributed") if KSpvalue > 0.05 else print(f"KS: {col} data is Not Normally Distributed")
# Out:
# SW: F=0.8 (Baseline) data is Normally Distributed
# SW: F=1.2 data is Normally Distributed
# SW: F=1.6 data is Normally Distributed
# SW: F=2.0 data is Normally Distributed
# KS: F=0.8 (Baseline) data is Normally Distributed
# KS: F=1.2 data is Normally Distributed
# KS: F=1.6 data is Normally Distributed
# KS: F=2.0 data is Normally Distributed

# %%
# Data is confirmed for approximate normality -> Anova Statistical Testing
statistic, pvalue = stats.f_oneway(stats_df["F=0.8 (Baseline)"], stats_df["F=1.2"], stats_df["F=1.6"], stats_df["F=2.0"])
stmnt1 = f"ANOVA: (p= {pvalue} < 0.05). Null hypothesis rejected, distributions have a different population mean."
stmnt2 = f"ANOVA: (p= {pvalue} > 0.05). Null hypothesis not rejected, distributions have the same population mean."
print(stmnt1) if pvalue < 0.05 else print(stmnt2)
# Out:
# ANOVA: (p= 3.788493106037692e-20 < 0.05). Null hypothesis rejected, distributions have a different population mean.

# %%
# Confirmed that populations have a different mean -> t-tests on individual groups
pairs = [["F=0.8 (Baseline)", "F=1.2"], ["F=1.2", "F=1.6"], ["F=1.6", "F=2.0"]]
for i in range(3):
    statistic, pvalue = stats.ttest_ind(stats_df[pairs[i][0]], stats_df[pairs[i][1]])
    stmnt1 = f"T-test: {pairs[i][0]}/{pairs[i][1]} (pvalue= {pvalue} < 0.05). Reject that these samples have identical mean"
    stmnt2 = f"T-test: {pairs[i][0]}/{pairs[i][1]} (pvalue= {pvalue} > 0.05). Can't reject that these have identical mean"
    print(stmnt1) if pvalue < 0.05 else print(stmnt2)
# Out:
# T-test: F=0.8 (Baseline)/F=1.2 (pvalue= 3.1888707534090386e-07 < 0.05). Reject that these samples have identical mean
# T-test: F=1.2/F=1.6 (pvalue= 6.34435256142442e-09 < 0.05). Reject that these samples have identical mean
# T-test: F=1.6/F=2.0 (pvalue= 1.9951804469540942e-05 < 0.05). Reject that these samples have identical mean

# %% [markdown]
# All hypothesis that the samples are of identical mean can be rejected. This means that either longer duration testing is needed (50->100 days) to see if the mean PPS of these parameters start to converge, OR, testing of higher F values needs doing in the future to determine the limit of how aggressive PRDE can be before it experiences a loss of performance. Either way it can be seen that F has more of an impact on performance than k.
